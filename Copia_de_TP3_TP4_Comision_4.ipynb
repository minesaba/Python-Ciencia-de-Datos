# %% [markdown]
# <a href="https://colab.research.google.com/github/minesaba/Python-Ciencia-de-Datos/blob/main/Copia_de_TP3_TP4_Comision_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TRABAJO PRACTICO N 3

# %% [markdown]
# ***TEMAS A DESARROLLAR:***
#
# Nociones de Probabilidad, simulación de procesos aleatorios, cálculo de parámetros estadisticos: Media o Valor Esperado(PROMEDIO), Mediana, Desvio Estandar. DISTRIBUCIONES DE PROABABILIDAD más frecuentes, por ejemplo la Normal.

# %% [markdown]
# ## Funciones estadísticas para análisis exploratorio de datos
# A continuación se presentan ejemplos de funciones estadísticas para el análisis exploratorio de datos utilizando NumPy:

# %% [markdown]
# #### Crear array aleatorio
# En esta celda, se utiliza la función np.random.rand() de NumPy para crear un array de números aleatorios con una forma específica. Luego, se imprime el array.

# %%
import numpy as np
random_array = np.random.randint(0,10, (4,3))
print("Array aleatorio:", random_array)
# Out:
# Array aleatorio: [[0 5 8]
#  [5 5 9]
#  [8 7 5]
#  [9 0 0]]

# %% [markdown]
# #### Media
# En esta celda, se crea un array 'array' y se utiliza la función np.mean() de NumPy para calcular la media del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
media = np.mean(array)
print("Media:", media)
# Out:
# Media: 3.0

# %% [markdown]
# #### Desviación estándar
# En esta celda, se crea un array 'array' y se utiliza la función np.std() de NumPy para calcular la desviación estándar del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
desviacion_estandar = np.std(array)
print("Desviación estándar:", desviacion_estandar)
# Out:
# Desviación estándar: 1.4142135623730951

# %% [markdown]
# #### Varianza
# La función np.var() se utiliza para calcular la varianza de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
varianza = np.var(array)
print("Varianza:", varianza)
# Out:
# Varianza: 2.0

# %% [markdown]
# #### Valor mínimo
# En esta celda, se crea un array 'array' y se utiliza la función np.min() de NumPy para encontrar el valor mínimo del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
matriz=np.random.randint(-3,3,(5,5))
#minimo = np.min(array)
minimo = np.min(matriz, axis=0) #En una matriz bidimensional: axis=0 COLUMNA // axis=1 FILA (info de la web)
print("Valor mínimo:", minimo)
print( matriz)
# Out:
# Valor mínimo: [-2 -2 -2 -3 -3]
# [[-2  2  0 -3  0]
#  [ 2  1 -1  0 -3]
#  [ 1  2 -2 -1 -1]
#  [-1 -2 -2 -1 -3]
#  [-1  0  0  0  2]]

# %% [markdown]
# #### Valor máximo
# En esta celda, se crea un array 'array' y se utiliza la función np.max() de NumPy para encontrar el valor máximo del array. Luego, se imprime el resultado.

# %%
maximo = np.max(array)
print("Valor máximo:", maximo)
# Out:
# Valor máximo: 5

# %% [markdown]
# #### Gráfico de dispersión
# En esta celda, se crea un array 'x' con valores aleatorios y un array 'y' con valores aleatorios. Luego, se utiliza la biblioteca Matplotlib para trazar un gráfico de dispersión con 'x' en el eje x y 'y' en el eje y. También se agrega etiquetas y un título al gráfico.

# %%
x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de dispersión')
plt.show()

# %% [markdown]
# En esta celda, se crea un array 'data' con valores aleatorios siguiendo una distribución normal. Luego, se utiliza la biblioteca Matplotlib para trazar un histograma de 'data'. También se agrega etiquetas y un título al gráfico.

# %%
data = np.random.normal(0, 1, 1000)

plt.hist(data, bins=30)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma')
plt.show()

# %% [markdown]
# #### Mediana
# La función np.median() se utiliza para calcular la mediana de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
mediana = np.median(array)
print("Mediana:", mediana)
# Out:
# Mediana: 3.0

# %% [markdown]
# #### Percentiles
# La función np.percentile() se utiliza para calcular los percentiles de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
percentil_50 = np.percentile(array, 50)
print("Percentil 50:", percentil_50)
# Out:
# Percentil 50: 3.0

# %% [markdown]
# # EJEMPLOS Y APLICACIÓNES

# %% [markdown]
# ***APLICACIÓN DE PROBABILIDAD***
#
# Se Realiza el lanzamiento de un dado EQUILIBRADO JUSTO, de manera reiterada con las mismas condiciones, y se anotan sus resultados= CARA O CRUZ.
#
# Se le pide al usuario que defina la cantidad N de lanzamientos y se calcula su frecuencia relativa= 'PROBABILIDAD' de obtener cara o cruz. Se obtiene los siguientes resultados:

# %%
import numpy as np
n=int(input('ingrese la cantidad de simulación o lanzamientos'))

#========= FORMA 1 DE SIMULAR LANZAMIENTO DE UN DADO============
dado=[]
cara=0
cruz=0
for i in range(n):
  dado.append(np.random.rand(1))
  dado1=np.array(dado)
  if dado1[i]<0.5:
    #print('salio cara')
    #print(dado[i])
    cara +=1
  else:
    #print('salio cruz')
    #print(dado[i])
    cruz +=1
# Out:
# ingrese la cantidad de simulación o lanzamientos50

# %%
#  mostrar la probailidad frecuencista de el lanzamiento de un dado
prom_cara=cara/n
prom_cruz=cruz/n
print('la probabilidad aproximada en '+str(n)+' lanzamientos de sacar CARA es:', prom_cara)
print('la probabilidad aproximada en '+str(n)+' lanzamientos de sacar CRUZ es:', prom_cruz)
# Out:
# la probabilidad aproximada en 100 lanzamientos de sacar CARA es: 0.47
# la probabilidad aproximada en 100 lanzamientos de sacar CRUZ es: 0.53

# %%
#========== FORMA COMPACTA DE SIMULAR USANDO NUMPY===========
m=int(input('ingrese la cantidad de simulación o lanzamientos'))
lanzamientos = np.random.randint(0, 2, m)

# Calcular las probabilidades

probabilidad_cara = np.sum(lanzamientos ==0 ) / len(lanzamientos)
probabilidad_sello = np.sum(lanzamientos== 1) / len(lanzamientos)

print(f"Probabilidad de cara: {probabilidad_cara:.2f}")
print(f"Probabilidad de sello: {probabilidad_sello:.2f}")
# Out:
# ingrese la cantidad de simulación o lanzamientos100
# Probabilidad de cara: 0.53
# Probabilidad de sello: 0.47

# %%
import matplotlib.pyplot as plt
x=np.array(range(2))
y=np.array([probabilidad_cara, probabilidad_sello])

plt.bar(x,y)
plt.xlabel('Opción')
plt.ylabel('Frecuencia relativa')
plt.title('Histograma del lanzamiento de una moneda equilibrada')
plt.show()

# %% [markdown]
# # EJERCICIOS

# %% [markdown]
# ##***EJERCICIO 1***
#
# Simular el lanzamiento de un dado eqilibrado de 6 caras.
#
#
# *   Mostrar la probabilida aproximada de obtener el número 2, 3 y 5
# *   Graficar el histograma de las probabilidades

# %%
import numpy as np
n=int(input('ingrese la cantidad de lanzamientos: '))

#========= FORMA 1 DE SIMULAR LANZAMIENTO DE UN DADO============
lanzamientos = np.random.randint(1, 7, size=n)
dos = 0
tres = 0
cinco = 0

for lanzamiento in lanzamientos:
    if lanzamiento == 2:
        dos += 1
    elif lanzamiento == 3:
        tres += 1
    elif lanzamiento == 5:
        cinco += 1

# CÁLCULO DE PROBABILIDADES
probabilidad_2 = dos / n
probabilidad_3 = tres / n
probabilidad_5 = cinco / n

# RESULTADOS
print(f"Probabilidad de dos: {probabilidad_2:.2f}")
print(f"Probabilidad de tres: {probabilidad_3:.2f}")
print(f"Probabilidad de cinco: {probabilidad_5:.2f}")
# Out:
# ingrese la cantidad de lanzamientos: 40
# Probabilidad de dos: 0.23
# Probabilidad de tres: 0.23
# Probabilidad de cinco: 0.12

# %%
#HISTOGRAMA DE PROBABILIDADES
import matplotlib.pyplot as plt
x=np.array(range(3))
y=np.array([probabilidad_2, probabilidad_3, probabilidad_5])
plt.bar(x,y,color='red')
plt.xlabel('Opciones')
plt.ylabel('Frecuencia relativa')
plt.title('Histograma del lanzamiento de un dado')
plt.show()

# %% [markdown]
# ## EJERCICIO 4
#
# Dada la base de datos de ventas diarias durante una semana, de un negocio con 4 productos.- VER EJERCICIO PARTE 2 PRACTICO N 2- Realizar el siguiente análisis de datos para poder obtener información y planificar una estrategia de ventas.
#
#
# 1.   Calcular la media en la ventas por cada producto y la mediana. Plotear estos nuevos datos en un gráfico de barra.
# 2.    Calcular la media en la ventas por DÍA y la mediana. Plotear estos nuevos datos en un gráfico de TRAZO DE LINEAS.
# 3.   Realizar una conclusión en función las graficas y sugerir al menos 5 estrategias de venta o inversión de manera de potenciar este negocio.
# 4.   Calcular el desvio estandar de los datos por cada producto y concluir para cada producto como es su rango de variabilidad en las ventas de los mismos.Plotear los datos de ventas de la semana de los productos con mayor y menor desvio estandar y evidenciar la variabilidad indicada en el parametro *'DESVIO ESTANDAR'*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Creo listas de Python (de cada producto)

a=[20, 15, 25, 30, 18, 22, 24]  #Producto A
b=[12, 20, 14, 8, 15, 18, 16]   #Producto B
c=[35, 28, 32, 30, 26, 24, 30]  #Producto C
d=[40, 38, 45, 42, 39, 41, 37]  #Producto D

# %%
# Creo el array de numpy (de cada producto)

import numpy as np

matriz = np.array([a, b, c, d])

print(matriz)
# Out:
# [[20 15 25 30 18 22 24]
#  [12 20 14  8 15 18 16]
#  [35 28 32 30 26 24 30]
#  [40 38 45 42 39 41 37]]

# %%
# 1) Calcular la media en la ventas por cada producto y la mediana.

media_a = np.mean(a)
media_b = np.mean(b)
media_c = np.mean(c)
media_d = np.mean(d)
mediana_a = np.median(a)
mediana_b = np.median(b)
mediana_c = np.median(c)
mediana_d = np.median(d)

print(f"MEDIA = A: {media_a} ", f"B: {media_b} ", f"C: {media_c} ", f"D: {media_d} ")
print(f"MEDIANA = A: {mediana_a} ", f"B: {mediana_b} ", f"C: {mediana_c} ", f"D: {mediana_d} ")
# Out:
# MEDIA = A: 22.0  B: 14.714285714285714  C: 29.285714285714285  D: 40.285714285714285
# MEDIANA = A: 22.0  B: 15.0  C: 30.0  D: 40.0

# %%
# 1) Plotear estos nuevos datos en un gráfico de barra.
import matplotlib.pyplot as plt

#MEDIA
x = np.array(range(4))
plt.bar(x, [media_a, media_b, media_c, media_d], color='red')
plt.ylabel("Valor de ventas")
plt.xlabel("Productos A, B, C, D")
plt.title("Ventas por producto (media)")
plt.show()

#MEDIANA
x = np.array(range(4))
plt.bar(x, [mediana_a, mediana_b, mediana_c, mediana_d], color='green')
plt.ylabel("Valor de ventas")
plt.xlabel("Productos A, B, C, D")
plt.title("Ventas por producto (mediana)")
plt.show()

# %%
# 1) Calcular la media en la ventas por DÍA y la mediana.

media_por_dia = np.mean(matriz, axis=0)
mediana_por_dia = np.median(matriz, axis=0)

print(media_por_dia)
print(mediana_por_dia)
# Out:
# [26.75 25.25 29.   27.5  24.5  26.25 26.75]
# [27.5 24.  28.5 30.  22.  23.  27. ]

# %%
# 2) Plotear estos nuevos datos en un gráfico de TRAZO DE LINEAS.
#MEDIA
dias = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']
plt.plot(dias, media_por_dia, marker='o', color='red')
plt.xlabel('Días')
plt.ylabel('Ventas')
plt.title('Ventas por día (media)')
plt.grid(True)
plt.show()

#MEDIANA
dias = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']
plt.plot(dias, mediana_por_dia, marker='o', color='green')
plt.xlabel('Días')
plt.ylabel('Ventas')
plt.title('Ventas por día (mediana)')
plt.grid(True)
plt.show()

# %% [markdown]
# # CONCLUSIÓN
# ## Estrategias de ventas o de inversión
# Los días miércoles y jueves las ventas son mayores (es posible que se deba a alguna promoción).
# Los días viernes y los martes las ventas descienden.
# Propongo estas 5 estrategias:
# - Incorporar una promoción los martes y los viernes.
# - Incorporar un descuento especial los sábados.
# - Siendo que el producto B es el más flojo en ventas, reforzar su colocación en el mercado.
# - Incorporar un descuento en la compra de tres productos (para potenciar a los menos vendidos)
# - Amplicar la publicidad en los días de menores ventas.

# %%
# 4) Calcular el desvio estándar de los datos por cada producto y concluir para cada producto como es su rango de variabilidad en las ventas de los mismos.

desv_estandar = np.std(matriz, axis=1)

for i, producto in enumerate(['A', 'B', 'C', 'D']):
    print(f"Desvío estándar de Producto {producto}: {desv_estandar[i]}")
# Out:
# Desvío estándar de Producto A: 4.566962103755937
# Desvío estándar de Producto B: 3.653346243584121
# Desvío estándar de Producto C: 3.4106675389466634
# Desvío estándar de Producto D: 2.4907993963089563

# %%
# Plotear los datos de ventas de la semana de los productos con mayor y menor desvío estándar y evidenciar la variabilidad indicada en el parametro 'DESVIO ESTANDAR'

x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de dispersión')
plt.show()

# %% [markdown]
# ## EJERCICIO 5
#
# Solicitar al usuario que ingrese la cantidad N de datos a cargar. Luego generar de manera aleatoria los siguientes datos:
#
# * SEXO= 'MASCULINO', 'FEMENINO','NO ESPECIFICA'
# * EDAD= entre 28 y 60 años
# * ALTURA= entre un rango de 165.0 mts hasta 210 mts
# * PESO= entre un rango de 50  y 110 kg
# * HORAS DE DESCANSO diario= un número decimal
# * HORAS DE TRABAJO/ ESTUDIO diario= un número decimal
# * HORAS DE EJERCICIOS diario= un número decimal
#
# REalizar las siguientes indicaciones y extraer concluisiones sobre la información y la pooblación muestreada.
#
# 1.   Generar un array de dimensión 2 (matriz), con todos los datos ordenados, permitiendo visualizarlos como tabla.
# 2.   Suponiendo que la distribución de probabilidad de los datos muestrados de las N personas, se distribuyen en forma NORMAL. Encontrar la media en los datos de altura, peso, y horas de descanso, trabajo y ejercicios.
# 3.  Graficar la muestra o distribución de los datos  de pesos , y alturas en graficas separadas. Indicar el grado de variabilidad de sus datos
# 4.  Plotear de manera conjunta y encontrar si presentan correlación los datos de peso vs altura,
# 5. Plotear de manera conjunta los datos de horas de descanso, estudio y ejercicio

# %%
import numpy as np
import matplotlib.pyplot as plt

def generar_datos(N):
    sexo = np.random.choice(['MASCULINO', 'FEMENINO', 'NO ESPECIFICA'], N ,[0.4, 0.5, 0.1])  # Por ejemplo, 40% masculino, 50% femenino, 10% no especificado)
    # Generar edades con distribución normal
    edad =np.random.normal(44, 6, N)
    edad=np.clip(np.around(edad),28,60)
    # Generar alturas, pesos y otras características
    altura = np.random.normal(180, 10, N)
    altura = np.clip(np.around(altura, decimals=1), 150.0, 210.0)

    peso = np.random.normal(80, 15, N)
    peso = np.clip(np.around(peso, decimals=1), 40.0, 130.0)

    horas_trabajo_estudio = np.random.normal(10, 2, N)
    horas_trabajo_estudio = np.clip(np.around(horas_trabajo_estudio, decimals=1), 4.0, 12.0)

    horas_ejercicio = np.random.normal(1, 0.5, N)
    horas_ejercicio = np.clip(np.around(horas_ejercicio, decimals=1), 0, 2)

    horas_descanso = 24 - horas_trabajo_estudio - horas_ejercicio

    datos = np.column_stack((sexo, edad, altura, peso, horas_descanso, horas_trabajo_estudio, horas_ejercicio))
    return datos

cantidad_datos = int(input("Ingrese la cantidad de datos para cargar: "))
datos = generar_datos(cantidad_datos)

campos = ['SEXO','EDAD', 'ALTURA','PESO','HORAS DE DESCANSO diario','HORAS DE TRABAJO/ESTUDIO diario','HORAS DE EJERCICIOS diario']

for d in datos:
    for campo, valor in zip(campos, d): #esto lo encontré en la web (y me sirve para ver los resultados)
        print(f"{campo}: {valor}")
    print("\n")
# Out:
# Ingrese la cantidad de datos para cargar: 20
# SEXO: NO ESPECIFICA
# EDAD: 51.0
# ALTURA: 176.0
# PESO: 80.1
# HORAS DE DESCANSO diario: 13.1
# HORAS DE TRABAJO/ESTUDIO diario: 9.6
# HORAS DE EJERCICIOS diario: 1.3
#
#
# SEXO: NO ESPECIFICA
# EDAD: 50.0
# ALTURA: 170.4
# PESO: 78.8
# HORAS DE DESCANSO diario: 10.1
# HORAS DE TRABAJO/ESTUDIO diario: 12.0
# HORAS DE EJERCICIOS diario: 1.9
#
#
# SEXO: MASCULINO
# EDAD: 47.0
# ALTURA: 170.8
# PESO: 76.2
# HORAS DE DESCANSO diario: 12.8
# HORAS DE TRABAJO/ESTUDIO diario: 11.1
# HORAS DE EJERCICIOS diario: 0.1
#
#
# SEXO: NO ESPECIFICA
# EDAD: 48.0
# ALTURA: 167.7
# PESO: 63.0
# HORAS DE DESCANSO diario: 14.6
# HORAS DE TRABAJO/ESTUDIO diario: 9.0
# HORAS DE EJERCICIOS diario: 0.4
#
#
# SEXO: NO ESPECIFICA
# EDAD: 37.0
# ALTURA: 186.2
# PESO: 76.5
# HORAS DE DESCANSO diario: 11.7
# HORAS DE TRABAJO/ESTUDIO diario: 12.0
# HORAS DE EJERCICIOS diario: 0.3
#
#
# SEXO: MASCULINO
# EDAD: 52.0
# ALTURA: 169.5
# PESO: 92.9
# HORAS DE DESCANSO diario: 11.5
# HORAS DE TRABAJO/ESTUDIO diario: 11.6
# HORAS DE EJERCICIOS diario: 0.9
#
#
# SEXO: FEMENINO
# EDAD: 49.0
# ALTURA: 175.7
# PESO: 43.0
# HORAS DE DESCANSO diario: 13.6
# HORAS DE TRABAJO/ESTUDIO diario: 10.0
# HORAS DE EJERCICIOS diario: 0.4
#
#
# SEXO: FEMENINO
# EDAD: 48.0
# ALTURA: 194.4
# PESO: 112.2
# HORAS DE DESCANSO diario: 14.9
# HORAS DE TRABAJO/ESTUDIO diario: 8.4
# HORAS DE EJERCICIOS diario: 0.7
#
#
# SEXO: NO ESPECIFICA
# EDAD: 49.0
# ALTURA: 192.6
# PESO: 74.2
# HORAS DE DESCANSO diario: 14.2
# HORAS DE TRABAJO/ESTUDIO diario: 9.8
# HORAS DE EJERCICIOS diario: 0.0
#
#
# SEXO: FEMENINO
# EDAD: 44.0
# ALTURA: 190.7
# PESO: 78.5
# HORAS DE DESCANSO diario: 15.200000000000001
# HORAS DE TRABAJO/ESTUDIO diario: 8.1
# HORAS DE EJERCICIOS diario: 0.7
#
#
# SEXO: MASCULINO
# EDAD: 43.0
# ALTURA: 172.9
# PESO: 93.4
# HORAS DE DESCANSO diario: 14.2
# HORAS DE TRABAJO/ESTUDIO diario: 8.9
# HORAS DE EJERCICIOS diario: 0.9
#
#
# SEXO: MASCULINO
# EDAD: 48.0
# ALTURA: 190.0
# PESO: 62.1
# HORAS DE DESCANSO diario: 10.1
# HORAS DE TRABAJO/ESTUDIO diario: 11.9
# HORAS DE EJERCICIOS diario: 2.0
#
#
# SEXO: FEMENINO
# EDAD: 45.0
# ALTURA: 174.6
# PESO: 59.5
# HORAS DE DESCANSO diario: 14.5
# HORAS DE TRABAJO/ESTUDIO diario: 8.3
# HORAS DE EJERCICIOS diario: 1.2
#
#
# SEXO: MASCULINO
# EDAD: 39.0
# ALTURA: 178.8
# PESO: 74.9
# HORAS DE DESCANSO diario: 11.6
# HORAS DE TRABAJO/ESTUDIO diario: 12.0
# HORAS DE EJERCICIOS diario: 0.4
#
#
# SEXO: MASCULINO
# EDAD: 45.0
# ALTURA: 197.8
# PESO: 76.1
# HORAS DE DESCANSO diario: 14.200000000000001
# HORAS DE TRABAJO/ESTUDIO diario: 8.7
# HORAS DE EJERCICIOS diario: 1.1
#
#
# SEXO: FEMENINO
# EDAD: 57.0
# ALTURA: 175.0
# PESO: 71.4
# HORAS DE DESCANSO diario: 10.8
# HORAS DE TRABAJO/ESTUDIO diario: 12.0
# HORAS DE EJERCICIOS diario: 1.2
#
#
# SEXO: FEMENINO
# EDAD: 40.0
# ALTURA: 179.5
# PESO: 75.6
# HORAS DE DESCANSO diario: 12.8
# HORAS DE TRABAJO/ESTUDIO diario: 10.6
# HORAS DE EJERCICIOS diario: 0.6
#
#
# SEXO: MASCULINO
# EDAD: 44.0
# ALTURA: 181.0
# PESO: 53.9
# HORAS DE DESCANSO diario: 14.6
# HORAS DE TRABAJO/ESTUDIO diario: 8.4
# HORAS DE EJERCICIOS diario: 1.0
#
#
# SEXO: MASCULINO
# EDAD: 47.0
# ALTURA: 170.6
# PESO: 98.2
# HORAS DE DESCANSO diario: 12.200000000000001
# HORAS DE TRABAJO/ESTUDIO diario: 10.6
# HORAS DE EJERCICIOS diario: 1.2
#
#
# SEXO: FEMENINO
# EDAD: 46.0
# ALTURA: 183.6
# PESO: 60.9
# HORAS DE DESCANSO diario: 14.0
# HORAS DE TRABAJO/ESTUDIO diario: 9.1
# HORAS DE EJERCICIOS diario: 0.9

# %%
# 1) Generar un array de dimensión 2 (matriz), con todos los datos ordenados, permitiendo visualizarlos como tabla.
matriz_datos = np.array(datos)

print(matriz_datos)
# Out:
# [['NO ESPECIFICA' '51.0' '176.0' '80.1' '13.1' '9.6' '1.3']
#  ['NO ESPECIFICA' '50.0' '170.4' '78.8' '10.1' '12.0' '1.9']
#  ['MASCULINO' '47.0' '170.8' '76.2' '12.8' '11.1' '0.1']
#  ['NO ESPECIFICA' '48.0' '167.7' '63.0' '14.6' '9.0' '0.4']
#  ['NO ESPECIFICA' '37.0' '186.2' '76.5' '11.7' '12.0' '0.3']
#  ['MASCULINO' '52.0' '169.5' '92.9' '11.5' '11.6' '0.9']
#  ['FEMENINO' '49.0' '175.7' '43.0' '13.6' '10.0' '0.4']
#  ['FEMENINO' '48.0' '194.4' '112.2' '14.9' '8.4' '0.7']
#  ['NO ESPECIFICA' '49.0' '192.6' '74.2' '14.2' '9.8' '0.0']
#  ['FEMENINO' '44.0' '190.7' '78.5' '15.200000000000001' '8.1' '0.7']
#  ['MASCULINO' '43.0' '172.9' '93.4' '14.2' '8.9' '0.9']
#  ['MASCULINO' '48.0' '190.0' '62.1' '10.1' '11.9' '2.0']
#  ['FEMENINO' '45.0' '174.6' '59.5' '14.5' '8.3' '1.2']
#  ['MASCULINO' '39.0' '178.8' '74.9' '11.6' '12.0' '0.4']
#  ['MASCULINO' '45.0' '197.8' '76.1' '14.200000000000001' '8.7' '1.1']
#  ['FEMENINO' '57.0' '175.0' '71.4' '10.8' '12.0' '1.2']
#  ['FEMENINO' '40.0' '179.5' '75.6' '12.8' '10.6' '0.6']
#  ['MASCULINO' '44.0' '181.0' '53.9' '14.6' '8.4' '1.0']
#  ['MASCULINO' '47.0' '170.6' '98.2' '12.200000000000001' '10.6' '1.2']
#  ['FEMENINO' '46.0' '183.6' '60.9' '14.0' '9.1' '0.9']]

# %%
# 2) Suponiendo que la distribución de probabilidad de los datos muestrados de las N personas, se distribuyen en forma NORMAL. Encontrar la media en los datos de altura, peso, y horas de descanso, trabajo y ejercicios.

matriz_num = matriz_datos[:, 2:].astype(float) #Esto lo encontré en la web, me permite seleccionar los campos con datos flotantes (altura, peso, y horas de descanso, trabajo y ejercicios)

media_en_datos = np.mean(matriz_num, axis=0)

print(f"Media en altura, peso, horas de descanso, trabajo y ejercicio {media_en_datos}")
# Out:
# Media en altura, peso, horas de descanso, trabajo y ejercicio [179.89   75.07   13.035  10.105   0.86 ]

# %%
# 3) Graficar la muestra o distribución de los datos de pesos y alturas en graficas separadas. Indicar el grado de variabilidad de sus datos.

pesos = matriz_datos[:, 3].astype(float)
alturas = matriz_datos[:, 2].astype(float)

# Calculo la variabilidad variabilidad
pesos_std = np.std(pesos)
alturas_std = np.std(alturas)

# Gráfico pesos

plt.subplot(1, 2, 1)
plt.scatter(range(len(pesos)), pesos, color='b', label='Pesos')
plt.axhline(np.mean(pesos), color='r', linestyle='dashed')
plt.xlabel('Datos')
plt.ylabel('Peso')
plt.title(f'Gráfico de pesos')
plt.tight_layout()
plt.show()

print(f"Desviación estándar (pesos) = {pesos_std:.2f}")

# Gráfico alturas

plt.subplot(1, 2, 2)
plt.scatter(range(len(alturas)), alturas, color='g', label='Alturas')
plt.axhline(np.mean(alturas), color='r', linestyle='dashed')
plt.xlabel('Datos')
plt.ylabel('Alturas')
plt.title(f'Gráfico de alturas')
plt.tight_layout()
plt.show()

print(f"Desviación estándar (alturas) = {alturas_std:.2f}")
# Out:
# Desviación estándar (pesos) = 15.61
# Desviación estándar (alturas) = 8.99

# %%
# Plotear de manera conjunta y encontrar si presentan correlación los datos de peso vs altura.

plt.figure(figsize=(8, 6))
plt.scatter(pesos.astype(float), alturas.astype(float), color='b')
plt.xlabel('Peso')
plt.ylabel('Altura')
plt.title('Gráfico de correlación entre peso y altura')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Conclusión
# Entiendo que no guarda correlación, porque son datos aleaotorios.

# %%
# Plotear de manera conjunta los datos de horas de descanso, estudio y ejercicio.

# Aclaración = lo haré en dos gráficos diferentes.

horas_descanso = matriz_datos[:, -3].astype(float)
horas_estudio = matriz_datos[:, -2].astype(float)
horas_ejercicio = matriz_datos[:, -1].astype(float)

# Gráfico horas de descanso y horas de trabajo/estudio
plt.subplot(1, 2, 1)
plt.scatter(horas_descanso, horas_estudio, color='b')
plt.xlabel('Horas de descanso')
plt.ylabel('Horas de trabajo/estudio')
plt.title('Horas de descanso y horas de trabajo/estudio')
plt.grid(True)
plt.tight_layout()
plt.show()

# Gráfico horas de descanso y horas de ejercicio
plt.subplot(1, 2, 2)
plt.scatter(horas_descanso, horas_ejercicio, color='g')
plt.xlabel('Horas de descanso')
plt.ylabel('Horas de ejercicio')
plt.title('Horas de descanso y horas de ejercicio')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Ayuda Como generar los datos**

# %%
import numpy as np
import matplotlib.pyplot as plt

def generar_datos(N):
    sexo = np.random.choice(['MASCULINO', 'FEMENINO', 'NO ESPECIFICA'], N ,[0.4, 0.5, 0.1])  # Por ejemplo, 40% masculino, 50% femenino, 10% no especificado)
    # Generar edades con distribución normal
    edad =np.random.normal(44, 6, N)
    edad=np.clip(np.around(edad),28,60)
    # Generar alturas, pesos y otras características
    altura = np.random.normal(180, 10, N)
    altura = np.clip(np.around(altura, decimals=1), 150.0, 210.0)

    peso = np.random.normal(80, 15, N)
    peso = np.clip(np.around(peso, decimals=1), 40.0, 130.0)

    horas_trabajo_estudio = np.random.normal(10, 2, N)
    horas_trabajo_estudio = np.clip(np.around(horas_trabajo_estudio, decimals=1), 4.0, 12.0)

    horas_ejercicio = np.random.normal(1, 0.5, N)
    horas_ejercicio = np.clip(np.around(horas_ejercicio, decimals=1), 0, 2)

    horas_descanso = 24 - horas_trabajo_estudio - horas_ejercicio
    datos = np.column_stack((sexo, edad, altura, peso, horas_descanso, horas_trabajo_estudio, horas_ejercicio))
    return datos


# Solicitar al usuario la cantidad N de datos a cargar
N = 1000

# Generar datos aleatorios para N personas con distribución normal y límites específicos
datos = generar_datos(N)

# %% [markdown]
# # TRABAJO PRACTICO N 4

# %% [markdown]
# **Trabajo Practico Nº 4**
# Analisis sobre data set
#
# 1= Buscar los siguiente data set en la web
# * Titanic
# * Iris
# * Wine
# * Indian Diabetes
#
# 2- Explicar un data set , sus diferente Variables\
# 3- Decide justificando tu respuesta que tipo de categoria de variable son\
# 4- Detectar y arreglar los siguientes conceptos
# * Valores Ausente
# * Valores Atipicos
#
# 5- Sobre el dataset elegido , ¿se puede eliminar alguna fila o columna?\
#
# 6- Realizar analisis univariados
# * Grafico de frecuencia
# * Grafico de torta
# * Histograma
# * etc
#
# 7- En base a los graficos del punto 6 realizar distintas concluciones\
#
# 8- Realizar analisis de matriz corelacion y explicar que variable estan correlacionadas\
#
# PD Pueden Buscar data set de kaggle

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar el conjunto de datos
data_iris = sns.load_dataset("iris")
data_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# 2) Explicar un dataset, sus diferente variables
# Elegí el dataset IRIS para analizar

data_iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# ## RESPUESTA 2):
# Las diferences variables del dataset son: sepal_length, sepal_width, petal_length, petal_width, species (setosa, versicolor, virginica).

# %% [markdown]
# ## RESPUESTA 3), ¿qué tipos de variables son?
#
# SepalLengthCm,	SepalWidthCm, PetalLengthCm y PetalWidthCm son VARIABLES NUMÉRICAS. Representan mediciones (largo y ancho).
#
# Species es una VARIABLE CATEGÓRICA. Representan al tipo de especie.

# %%
# 4) Detectar y arreglar los siguientes conceptos (valores ausentes - valores atípicos).

print(data_iris.isnull().sum())

# No encontré valores ausentes

# Haré un gráfico para ver si hay valores atípicos

columnas_numericas = data_iris[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
sns.boxplot(data=columnas_numericas)
plt.title("Variables numéricas, ¿hay valores atípicos?")
plt.show()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
import numpy as np
#Cuartiles
q1 = np.percentile(columnas_numericas, 25)
q2 = np.percentile(columnas_numericas, 50)
q3 = np.percentile(columnas_numericas, 75)

print(q1, q2, q3)

plt.xticks([1], ['Datos'])
plt.grid(True)

plt.scatter(1, q1, color='red', label='Primer cuartil (Q1)')
plt.scatter(1, q2, color='green', label='Mediana (Q2)')
plt.scatter(1, q3, color='blue', label='Tercer cuartil (Q3)')
plt.plot(np.random.normal(1, 0.04, size=len(columnas_numericas)), columnas_numericas, 'cyan', alpha=0.6)
plt.legend()
plt.show()

iqr = q3 - q1
print("Rango intercuartil (IQR):", iqr)
# Out:
# 1.7 3.2 5.1
# Rango intercuartil (IQR): 3.3999999999999995

# %% [markdown]
# En este dataset no hay valores atípicos.

# %% [markdown]
# 5) Sobre el dataset elegido , ¿se puede eliminar alguna fila o columna?
#
# En este dataset no eliminaría ninguna fila (porque no hay valores nulos o atípicos), ni columnas (porque todas son necesarias para el análisis).

# %%
# 6) Realizar analisis univariados

#Gráfico de torta

species_counts = data_iris['species'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(species_counts, labels=species_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Proporcional de especies")
plt.show()

#Histograma

plt.figure(figsize=(8, 6))
plt.hist(columnas_numericas['petal_length'], bins=30, edgecolor='black', alpha=0.7)
plt.xlabel('Species')
plt.ylabel('Frecuencia')
plt.title('Histograma')
plt.show()

# %% [markdown]
#  7) En base a los graficos del punto 6 realizar distintas conclusiones
#
#  En cuanto a las especies: existe una proporción entre los 3 tipos (setosa, virgínica y versicolor).

# %%
# Realizar análisis de matriz de correlación y explicar qué variables estan correlacionadas.

matriz_correl = data_iris.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(matriz_correl, annot=True, cmap="viridis", vmin=-1, vmax=1)
plt.title("Matriz de Correlación de los datos del dataset Iris")
plt.show()
# Out:
# <ipython-input-69-239fcb9a4b81>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matriz_correl = data_iris.corr()
